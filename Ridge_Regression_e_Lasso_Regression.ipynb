# %% [markdown]
# <a href="https://colab.research.google.com/github/franciscoklaus/Machine_Learning/blob/main/Ridge_Regression_e_Lasso_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#reg = m1x1 + m2x2 + m3x3

# Regressão linear
#custo = Σm (regi - yi)²


# Regressão ridge
#custo = Σm 1i=1(regi - yi)² + lambda Σm i=1 mi²

#m1 = 1
#m2 = 4

# Técnicas de regularização
# https://medium.com/data-hackers/o-que-%C3%A9-regulariza%C3%A7%C3%A3o-l1-l2-6697ada36a51#:~:text=Regulariza%C3%A7%C3%A3o%20%C3%A9%20uma%20t%C3%A9cnica%20para,como%20La%C3%A7o%20e%20Ridge%20regression.

# %%
# Exemplo  de algoritmo de ridge regression
# Regularização L1 e L2 e regressão Lasso

#L2 -> eleva ao quadrado o peso ((Regressão) Função ridge)
#L1 -> pega o módulo de peso ((Regressão) Função Lasso)

# %%
# Exemplo em python usando Lasso Regression
import pandas as pd
pd.set_option('display.max_columns',21)
arquivo = pd.read_csv('/content/kc_house_data.csv')

# %%
arquivo.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
arquivo.drop('id',axis=1, inplace=True)
arquivo.drop('date',axis=1, inplace=True)
arquivo.drop('zipcode',axis=1, inplace=True)
arquivo.drop('lat', axis=1, inplace=True)
arquivo.drop('long',axis=1, inplace=True)

# %%
arquivo.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#    sqft_living15  sqft_lot15
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
modelo = LinearRegression()

# %%
y = arquivo['price']
x = arquivo.drop('price',axis=1)

# %%
from sklearn.model_selection import train_test_split
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.30,random_state=14)

# %%
modelo.fit(x_treino, y_treino)
resultado = modelo.score(x_teste, y_teste)
print(resultado)
# Out:
# 0.6538094196281007

# %%
# Usando função de Ridge
from sklearn.linear_model import Ridge
modeloRidge = Ridge(alpha=10)
modeloRidge.fit(x_treino, y_treino)
resultadoRidge = modeloRidge.score(x_teste, y_teste)
print(resultadoRidge)
# Out:
# 0.6545037069731696

# %%
# Usando função Lasso
from sklearn.linear_model import Lasso
modeloLasso = Lasso(alpha=10)
modeloLasso.fit(x_teste, y_teste)
resultadoLasso = modeloLasso.score(x_teste, y_teste)
print(resultadoLasso)
# Out:
# 0.6578551308425287
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.281e+14, tolerance: 8.199e+10
#   model = cd_fast.enet_coordinate_descent(
